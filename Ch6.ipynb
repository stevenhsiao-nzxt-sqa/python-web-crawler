# %% [markdown]
# # Pandas data clean, read, store

# %% [markdown]
# ## 6-1 Pandas basic usage
# * Pandas is hign performance data analysis python module

# %% [markdown]
# ### 6-1-1 Know Pandas' data atructure
# * There are two major data structure:
#     * Series: one dimension array, or we can said it's 2 arrays' combination(index & data)
#     * DataFrame: Multiple series, 2-diinsion array, it own the row index & series index

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6-1-2 Build Series & DataFrame object

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# * We can use list to build Series obj:

# %%
list = ["Bike", "Bus", "Car", "Truck"]
s = pd.Series(list)
print(list)
print("**********")
print(s)
# Out:
# ['Bike', 'Bus', 'Car', 'Truck']
# **********
# 0     Bike
# 1      Bus
# 2      Car
# 3    Truck
# dtype: object

# %% [markdown]
# #### Use Series obj to build DataFrame obj

# %%
import pandas as pd

s1 = pd.Series(["Bike","Bus","Car","Truck"])
s2 = pd.Series([3,4,6,2])
s3 = pd.Series([2,4,4,6])


# s1 = ["Bike","Bus","Car","Truck"]
# s2 = [3,4,6,2]
# s3 = [2,4,4,6]


data = {'種類': s1, '數量': s2, '輪數': s3 } 
df = pd.DataFrame(data) 
print(df)
# Out:
#       種類  數量  輪數
# 0   Bike   3   2
# 1    Bus   4   4
# 2    Car   6   4
# 3  Truck   2   6

# %% [markdown]
# #### Use Python dictionary to build DataFrame obj
# * Because Series also need to be built by python dictionary to build DataFrame, so we can use python dictionary to build DataFrame obj:

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
print(df)
# Out:
#       種類  數量  輪數
# 0   Bike   3   2
# 1    Bus   4   4
# 2    Car   6   4
# 3  Truck   2   6

# %% [markdown]
# #### Rearrange the row index & column index

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
labels = ["A","B","E","D"]
df.columns = ["Types", "Count", "Wheels"]
labels[2] = "C"
df.index = labels
print(df)
# Out:
#    Types  Count  Wheels
# A   Bike      3       2
# B    Bus      4       4
# C    Car      6       4
# D  Truck      2       6

# %% [markdown]
# #### Use specific column as row index
# * DataFrame can use set_index() method to assign row index, reset_index() method can reset to default number as index

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
df.set_index("種類", inplace=True)
print(df)
df.reset_index(inplace=True)
print(df)
# Out:
#        數量  輪數
# 種類
# Bike    3   2
# Bus     4   4
# Car     6   4
# Truck   2   6
#       種類  數量  輪數
# 0   Bike   3   2
# 1    Bus   4   4
# 2    Car   6   4
# 3  Truck   2   6

# %% [markdown]
# #### Add record & column
# * Add record in DataFrame, we can use append() method

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
s = pd.Series({'種類':"Bicycle",'數量':5,'輪數':2}) 
df2 = df.append(s, ignore_index=True)
print(df2.tail())

print("**************")

df["載客數"] = [1, 20, 4, 2]
print(df)
# Out:
#         種類  數量  輪數
# 0     Bike   3   2
# 1      Bus   4   4
# 2      Car   6   4
# 3    Truck   2   6
# 4  Bicycle   5   2
# **************
#       種類  數量  輪數  載客數
# 0   Bike   3   2    1
# 1    Bus   4   4   20
# 2    Car   6   4    4
# 3  Truck   2   6    2

# %% [markdown]
# #### Remove record & column

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
df.set_index("種類", inplace=True)
print(df)
print("**************")
df2 = df.drop(["Bus", "Truck"])
print(df2)
print("**************")
df3 = df.drop(df.index[[0, 2]])
print(df3)
print("**************")
df4 = df.drop(["輪數"], axis=1)    # Steven: Probably because there has chance multiple ["輪數"] column existed 
print(df4)
# Out:
#        數量  輪數
# 種類
# Bike    3   2
# Bus     4   4
# Car     6   4
# Truck   2   6
# **************
#       數量  輪數
# 種類
# Bike   3   2
# Car    6   4
# **************
#        數量  輪數
# 種類
# Bus     4   4
# Truck   2   6
# **************
#        數量
# 種類
# Bike    3
# Bus     4
# Car     6
# Truck   2

# %% [markdown]
# ### 6-1-3 Shows DataFrame data & extract data
# * DataFrame's obj df related method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Shows head & tail data

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
print(df.head(2))
print(df.tail(3))
# Out:
#      種類  數量  輪數
# 0  Bike   3   2
# 1   Bus   4   4
#       種類  數量  輪數
# 1    Bus   4   4
# 2    Car   6   4
# 3  Truck   2   6

# %% [markdown]
# #### Fetch DataFrame obj's row index、column & data

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
print(df)
print("***")
print(df.index)
print("***")
print(df.columns)
print("***")
print(df.values)
print("***")
print(df.values[2])
print("***")
print(df.values[1][2])
# Out:
#       種類  數量  輪數
# 0   Bike   3   2
# 1    Bus   4   4
# 2    Car   6   4
# 3  Truck   2   6
# ***
# RangeIndex(start=0, stop=4, step=1)
# ***
# Index(['種類', '數量', '輪數'], dtype='object')
# ***
# [['Bike' 3 2]
#  ['Bus' 4 4]
#  ['Car' 6 4]
#  ['Truck' 2 6]]
# ***
# ['Car' 6 4]
# ***
# 4

# %% [markdown]
# #### Shows DataFrame obj's records & shape

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
print(len(df))
print(df.shape)
# Out:
# 4
# (4, 3)

# %% [markdown]
# #### Show DataFrame obj's summarize info
# * Can use info() & describe() method

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': [2,4,4,6] } 
df = pd.DataFrame(data) 
print(df.info())
print("***")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   種類      4 non-null      object
#  1   數量      4 non-null      int64
#  2   輪數      4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes
# None
# ***
#              數量        輪數
# count  4.000000  4.000000
# mean   3.750000  4.000000
# std    1.707825  1.632993
# min    2.000000  2.000000
# 25%    2.750000  3.500000
# 50%    3.500000  4.000000
# 75%    4.500000  4.500000
# max    6.000000  6.000000

# %% [markdown]
# ### 6-1-4 Select, filter & sort DataFrame data

# %%
import pandas as pd

data = {'種類': ["Bike","Bus","Car","Truck"],
        '數量': [3,4,6,2],
        '輪數': ["2","4","4","6"] } 
df = pd.DataFrame(data, index=["A","B","C","D"]) 
print(df)
# Out:
#       種類  數量 輪數
# A   Bike   3  2
# B    Bus   4  4
# C    Car   6  4
# D  Truck   2  6

# %% [markdown]
# #### Use column index select one or multiple column

# %%
print(df["種類"])
print("***")
print(df[["數量", "輪數"]].head(3))
# Out:
# A     Bike
# B      Bus
# C      Car
# D    Truck
# Name: 種類, dtype: object
# ***
#    數量 輪數
# A   3  2
# B   4  4
# C   6  4

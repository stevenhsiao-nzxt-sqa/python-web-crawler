# %% [markdown]
# # BeautifulSoup Parse & Extract Data

# %% [markdown]
# ## 5-1 Use BeautifulSoup to extract web data
# * Python can use BeautifulSoup analysize HTML, and get the target data from  it

# %% [markdown]
# ### 5-1-1 BeautifulSoup Basic Usage

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (0.0.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: beautifulsoup4 in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (from beautifulsoup4->bs4) (2.3.2.post1)

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\steve\.virtualenvs\python-web-crawler-c0cpmwo0\lib\site-packages (4.9.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# usage:
# from bs4 import BeautifulSoup

# soup = BeautifulSoup(contents, "lxml")

# %% [markdown]
# * 1st parameter is HTML contends downloaded
# * 2nd parameter is the parser, lxml is faster than the default "html.parser"

# %% [markdown]
# from soup object extract target tag: ("a" is hyperlink tag)

# %%
# tags = soup("a")

# %% [markdown]
# After get all "a" tag object, we can loop it:

# %%
# for tag in tags
#     print(tag.get("href", None))

# %% [markdown]
# ### Sample code:

# %%
import requests
from bs4 import BeautifulSoup 

url = "https://fchart.github.io/"
response = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "lxml")
    tags = soup("a")
    for tag in tags:
        print(tag.get("href", None))
else:
    print("Error! HTTP request fail...")
# Out:
# #page-top
# #fchart
# #flowchart
# #codeeditor
# #python
# #node
# #arduino
# #ardublockly
# #microbit
# #doc
# #
# https://hueyanchen.github.io/
# http://blockly.is-best.net/
# https://fchart.github.io/MyMind/index_zh-Hant.html
# https://drive.google.com/file/d/1NKyh1nl1vwyhHf7mOLj7cxb2g6SpSx57/view?usp=sharing
# https://drive.google.com/file/d/1PeCYYT-xA3v9Wn7LiwM2wq8ltvJVwGqY/view?usp=sharing
# https://github.com/fchart/fChartExamples2
# https://fchart.github.io/fChart6%E4%BD%BF%E7%94%A8%E6%89%8B%E5%86%8A.pdf
# https://fchart.github.io/tutorial/
# https://fchart.github.io
# http://fchart.is-best.net
# https://fchart.github.io/fChart6%E4%BD%BF%E7%94%A8%E6%89%8B%E5%86%8A.pdf
# #
# https://drive.google.com/file/d/1NKyh1nl1vwyhHf7mOLj7cxb2g6SpSx57/view?usp=sharing
# fChart使用說明.htm
# #
# #
# #
# https://drive.google.com/file/d/1NKyh1nl1vwyhHf7mOLj7cxb2g6SpSx57/view?usp=sharing
# https://hueyanchen.github.io/
# fChart使用說明.htm
# https://drive.google.com/file/d/1VspHydl48PIoeVT7sjw4Gx307UrJUNHB/view?usp=sharing
# https://mega.nz/file/SNlw2TyY#XUIiHxhjY90iQsM0fa5Ys1RgaGkm0AmoZDPEU2amfRM
# https://drive.google.com/file/d/1fiIEaE55--xofBrpK7h2SPXp0nLzi3tS/view?usp=sharing
# https://mega.nz/file/CIVEUA7b#Gr_BSUJRTFwgbSv6_kV8ev_SvXWSJ8o48J7JKRQuaHo
# https://drive.google.com/file/d/1RUK_1IO2Eu4NhC7sR-DmCrcICAjOUwO4/view?usp=sharing
# https://drive.google.com/file/d/1Mm5r9XIdt4yTkrZSuAd-nq5SdYErWDGg/view?usp=share_link
# https://mega.nz/file/zE8SnBja#nJAUXkKWWJdFi-_c0dIXFuqSMhCkh-VhAIHUycqf7tg
# https://drive.google.com/file/d/1EkUZPiNGmCNxzEPtDNkffyz5ngmLWa3M/view?usp=share_link
# https://mega.nz/file/KQVlRAhR#c7-tWIJ6Kzz7tcTkYHd1kmr8oDAicupkSCO9tO4O470
# https://drive.google.com/file/d/1hvnBeY67kOh8OSNqTCMC69qJyGFzDPzi/view?usp=sharing
# https://mega.nz/file/iUlRFY6K#aaZa9aVI3eODX_ZHEnwPmldj4r5yqHs3mPp_a4GBFxM
# https://drive.google.com/file/d/1oGrkL2Anld0q2oOeXlHZHqn8dqKQb2oJ/view?usp=sharing
# https://drive.google.com/file/d/1j28k603m6UrW19_armtFtKWXUopt_ZHb/view?usp=sharing
# https://mega.nz/file/7VVhFaSQ#2iFw13Iw6vDonMwsBVsvwlN7XhKpnBn7kfgyB4kqBrc
# https://drive.google.com/file/d/15P73WtLjmaqEvVVNa0m_IFP9xs89DvBC/view
# https://mega.nz/file/ydcUEATI#Vyr7OriYcqr7doJ66bDyvuqntGs64E3OLLjrI-ojF34
# https://drive.google.com/file/d/1WlAgVh9gQYjTzdHJmCFDfcjExy8FUKRc/view?usp=sharing
# https://mega.nz/file/CclhVSjY#ZyupR_jmkkK8lrNGxzuXLz-zwGesG-rZ27Imxt64H7M
# https://drive.google.com/file/d/1JGB222NhJOMc7cwqHFovsiEN3tmibI6d/view?usp=sharing
# https://drive.google.com/file/d/1edveDAfA7IfrqPGkLXenSpYd0kejwepv/view?usp=sharing
# https://mega.nz/file/2A0ghbpR#AHmzzgxPeh0_a2h-m0JwzPHyyG4IAs8ngmx8jqNAyJ8
# https://drive.google.com/file/d/1UC7uGxVo-xxjbGj5AL_5dS1TimRZ1s8h/view?usp=sharing
# https://drive.google.com/file/d/1Bmh37My3A_eeVacvecyzJyTu6lAwFFqA/view?usp=sharing
# https://drive.google.com/file/d/1gmiXape570wbYmgZcOLdkzX0lbMrfi17/view?usp=sharing
# https://drive.google.com/file/d/1tUZeVOQkS1YIL0PdZ0u5jgmBxcXGyuX4/view?usp=sharing
# https://mega.nz/file/nBV3gK7L#Ss9_syfqWikVFcCkgkD4gYIX9rF4_RUMhpeG6lhzbBA
# https://drive.google.com/file/d/1eJPJJ3v6kHV1kSMg9n4XYMZi8jPzFafa/view?usp=sharing
# https://drive.google.com/file/d/1g1QL9APHWXPdYX8MFaOPAqGnJMd6WsuE/view?usp=sharing
# https://mega.nz/file/uJ9ClRzQ#sJedtjXLfglCItkKJ4W1V1DGWjt2jOZYcWXErWOK_ww
# https://drive.google.com/file/d/1JGeFy09wFtpTdodYnjevgIdEc_3Ll9kQ/view?usp=sharing
# #
# #
# https://drive.google.com/file/d/1BL1v-hbrTdEXpTcvInBx4IduGT7qlBEr/view?usp=sharing
# https://mega.nz/file/KdNUVbTQ#wjFl6-iNNfZuVrbaWaJaXD1099R4JUyrJ2RuKW3gRQg
# https://drive.google.com/file/d/1-nK3S5nYxActBsxF-pP63XsLUnsd7CKb/view?usp=sharing
# https://mega.nz/file/7F93TAKJ#UCChyzf8rIdPN21KH8sPmXvoz_e9UU2Ve41nk_wZLVc
# fChartPython使用說明.html
# https://drive.google.com/file/d/1S3wpgIwy0_rERpLt1sDhNatT9hI-zm3p/view?usp=sharing
# https://mega.nz/file/XZkg3TpK#jqjl8191KtHcmUywLmG1mLegEBNRZ-eq-5-LrwIqRPU
# https://drive.google.com/file/d/1n-744s9LCbxSJ25cX8ke0qR1W7Ainm6s/view?usp=sharing
# https://mega.nz/file/KRlAgT7b#g2sbn1YeQkF1m0LcC1GH0Z2kq_60ishHDhPy5e11Keg
# https://drive.google.com/file/d/1323dhbPkZ1Pj1CqLQ45r-tfJQeuvqWRT/view?usp=sharing
# https://mega.nz/file/yIk2xDpB#s3AKcQBN5OTQD3Rg4i_0ECLnHvag-rz5R_ZPXIePlPM
# #
# #
# https://drive.google.com/file/d/1gdWFf4DBheVH8SuPrCuYaIYsNByx2t9V/view?usp=sharing
# https://mega.nz/#!aEEEiQ7Z!G_VXHVAn_l3mCxOmBLPq_ZWMFtkEmVLpWLfzWMuv3yY
# https://drive.google.com/file/d/1tvnq3yKp6BJtuh-itHaDUVZLC0G7Ap5Y/view
# https://mega.nz/file/TdkXACYK#VusZ9ZJebLEH9ZwAebQ5778Hz1lzahrp9j2BQ2Lbn14
# https://drive.google.com/file/d/1qyx0zxJIFTRmMtAY5G2AmreUKeOm94kC/view?usp=sharing
# https://mega.nz/file/WF9FGYzJ#3CZnzeK0PHYruqangJRVQhtuWG79014fzwqPjpQpBMk
# fChartNode使用說明.html
# #
# https://drive.google.com/file/d/1JTT2rcz1VOWx81HgW2e_MCHtyANkY3Qn/view?usp=sharing
# https://mega.nz/#!LNsyXSaR!fe4CxK9sNCvmEzvGjUE_TjJW4PtJtyJNEWYfgb8sz0g
# fChartArduino4.5使用說明.htm
# #
# https://drive.google.com/file/d/0B6TockxTwgQUcGk5a1o0RVpzNDQ/view?usp=sharing
# https://mega.nz/#!3ckhFQQY!lG5lDuW1rKnmJI5ikU13hJC5vazbmwCgmlN9m9FkL0c
# #
# #
# https://drive.google.com/file/d/1ZAHEh8rrC_RxRJ5XEUyd2JReV5Zap5C4/view?usp=sharing
# https://mega.nz/#!eY9SlSAA!sSNlzoyDf-1ZV2xdDWnDj6ZSEZ7gHbwcE5TVwW-e-0w
# https://media.readthedocs.org/pdf/microbit-micropython/latest/microbit-micropython.pdf
# https://drive.google.com/file/d/16ZAPNifmijNKG9BXRh93Rwm0KnHympyT/view?usp=sharing
# https://app.box.com/s/p9ze4e1c1q5tlgay4a8kxwoddjqafufq
# https://drive.google.com/file/d/1UF0NXUdK0gqQ33jhpX_xCt9sThee2Ft4/view?usp=sharing
# https://app.box.com/s/2jyxz2tw8afoo71p5895j8q7kqr7j2q9
# https://drive.google.com/file/d/1JvU4MDt6TD0V5h1NGQ8U5A_r-lZY4Qty/view?usp=sharing
# https://app.box.com/s/b5143gnb26jyghlsn7r837clcaovaa37
# https://drive.google.com/file/d/1KFx5JdYqc4jtNZ3_5aDEhdqwITiDVKc5/view?usp=sharing
# https://mega.nz/#!WBknGYCD!Cbw03FRMjy-gcFjay8quyBsoSVcADg1qQ9_6vKvFlN4
# https://drive.google.com/file/d/1bh0Utb5NxbU9vvVe7Re5MduPOWXeagRy/view?usp=sharing
# https://mega.nz/#!OM8kAIwZ!k6SgN8rh3aPEgXwm_FlsgiHjIrhqY20l-nRRTqbnN7k
# https://drive.google.com/file/d/1OwAM4cCOpA_Uv9UckKLIcPLt4-eO9xZk/view?usp=sharing
# https://mega.nz/#!vJVkEYRI!dbp3s8_hM3ng0MltEJPkH222yvOB3xSOki0PWzy1dNg
# https://www.tenlong.com.tw/items/9864630725?item_id=1011985
# https://www.tenlong.com.tw/items/9864632787?item_id=1023174
# https://www.tenlong.com.tw/items/9572192248?item_id=887436
# https://www.tenlong.com.tw/items/9864632760?item_id=1022152
# https://www.tenlong.com.tw/items/9863123226?item_id=1012678
# https://www.tenlong.com.tw/products/9789863124245
# https://drive.google.com/file/d/19dE_FOSq_tsOOZ_9nRuzCeEWh1USaOFJ/view?usp=sharing
# https://drive.google.com/file/d/1-nK3S5nYxActBsxF-pP63XsLUnsd7CKb/view?usp=sharing
# https://drive.google.com/file/d/1NSlLwYs5A9sjbeDIIm8VHjDYVhqgHZLm/view?usp=sharing
# https://drive.google.com/file/d/1gdWFf4DBheVH8SuPrCuYaIYsNByx2t9V/view?usp=sharing
# https://drive.google.com/file/d/1JTT2rcz1VOWx81HgW2e_MCHtyANkY3Qn/view?usp=sharing
# https://drive.google.com/file/d/1UF5BbavQzC3JZOV7xkvTvYcL5WJAsZWq/view?usp=sharing
# https://drive.google.com/file/d/12n-hXBzsgE942TsifWGIPl4qXF9pOZZa/view?usp=sharing
# https://drive.google.com/file/d/1zLs9eR6IH_xliJfd18hjfdNf9ISowxfS/view?usp=sharing
# https://drive.google.com/file/d/1YfIQjQ9Z7cz3ILcRGprFOgONSqoWGxqQ/view?usp=sharing
# https://drive.google.com/file/d/1YGBxT4r5xAGnEaG7TsUUx5UhJFOI97Xa/view?usp=sharing
# https://drive.google.com/file/d/122pDfI4Bw57vTldRkyuXA0cSu5vx2v0T/view?usp=sharing
# https://drive.google.com/file/d/1aRdXM2hDCaOFHIQEHWT6JIMV6RfTEBZV/view?usp=sharing
# https://drive.google.com/file/d/0B6TockxTwgQUN2t1MUlLQTIxVGc/view?usp=sharing
# https://drive.google.com/file/d/0B6TockxTwgQUYlNVSHpINGw2ajA/view?usp=sharing
# https://drive.google.com/file/d/0B6TockxTwgQUWnVtNUdoYXA0M3M/view?usp=sharing
# https://drive.google.com/file/d/0B6TockxTwgQUNmdOSmNibjM3OVE/view?usp=sharing
# https://drive.google.com/file/d/0B6TockxTwgQUMnpmZFRnem9kVHM/view?usp=sharing
# https://mega.nz/file/bNcW2QyC#NfK-VYCujZxdQt1F2RNwOPf1Aj7ph-bB673wQln3BO8
# https://mega.nz/file/udVBVSwC#BMjBsyJxmL9I4zupRhqFrxDxUu35w1vN8Z7H56chOCM
# https://mega.nz/#!PYUxjSgR!hhdU3pzSvpuJEPPO7mGc9UdsFUP-YIR_x6S2d7XEPQc
# https://mega.nz/#!aEEEiQ7Z!G_VXHVAn_l3mCxOmBLPq_ZWMFtkEmVLpWLfzWMuv3yY
# https://mega.nz/#!LNsyXSaR!fe4CxK9sNCvmEzvGjUE_TjJW4PtJtyJNEWYfgb8sz0g
# https://mega.nz/#!jNNxxCLT!QWwmUyOXTlS_0OQm_7QVNOwZaScvsi3wIxsIvkB1Fe8
# https://mega.nz/#!eE0EUAjZ!7zgBcHHQPtBggV50XF-v7MYgqtoApC_ANXv9xIr35A8
# https://mega.nz/#!rEdizaAb!6bkyIN1JGkwS618SifKFF1kdGvDXNZGjCVfbI4ieJwI
# https://mega.nz/#!eZMgRKJL!p8SZgjMj4R6Ov0cb836vmDtoLIb587TddzgqrrQhJ6g
# https://mega.nz/#!2VsHEBJJ!whVtiXjc37a-uD0cMljCJ7Le7iV3cqJRBh8JFHH05Oo
# https://mega.nz/#!qQdBVKQa!huTtgYsVQF44-FrfA3wi9sNh54TICTzuR2qdMeVhWqw
# https://mega.nz/#!LV9WhCAZ!XgvEtQ48OMkCJgya9CADJTFjij2Jhf9Ng-AGcr6Io74
# https://mega.nz/#!CVVnAJQT!3FlAub7Vk0OylH5m8n32wDc_hn8F4d3VXuCb3bGvmJk
# https://mega.nz/#!fQMHBDrT!i-M5Vlqw7Rb_m-U7itLJ0zhpmHbSr30eVLE3lsc6DyY
# https://mega.nz/#!uBMgSbpC!WUVi6lyLxmvvi3ppmKDOH9oxjiEu2I2a-rZaEbtGXew
# https://mega.nz/#!Scc1GDRA!u8AAtjdfeWxN49O6O929qMXXmszM-LzG0D6TE7ZKrew
# https://mega.nz/#!yY0DwAxA!b8NDb19w9Sp7PibH4JedhLQGoepO1cN4grK_4idGDOo
# https://mega.nz/#!3REjiLaa!bwXMhIbnZNBR1GtA4w-QDnPJFjJsbJjq8Oh5tnjfWD8
# https://github.com/fchart/fChartExamples
# https://github.com/fchart/fChartExamples2
# https://drive.google.com/file/d/1ThvyPWVlyC7ktqnwyMqwx0mo8q9z8p71/view?usp=sharing
# https://mega.nz/#!adsCWKoC!by9fLvh_TerQFptGEdOYaUHjz8ReL72TrH0etAIasv8
# https://drive.google.com/file/d/1tZ2q_12P3tA6mIVlhWvVbw3rrZAubNMn/view?usp=sharing
# https://mega.nz/#!nFVxzCjC!qOyLgLydA5XH8TkxOX5jDwUKqnm4ENnQfxYTJ8nDbKc
# https://drive.google.com/file/d/1Qm76WYTl4Xh3fUKWmVv1sk0wXFG6a0kX/view?usp=sharing
# https://mega.nz/#!iddw2AhD!OBDhLh6ELwMe4bloA10nV4KAm8rsYXTzZzwn8W4FeQ8
# https://drive.google.com/file/d/0B6TockxTwgQUcGk5a1o0RVpzNDQ/view?usp=sharing
# https://mega.nz/#!3ckhFQQY!lG5lDuW1rKnmJI5ikU13hJC5vazbmwCgmlN9m9FkL0c
# https://drive.google.com/file/d/1k0RUE54aHftn59-1WLAr6dGt6Gci05w7/view?usp=sharing
# https://mega.nz/#!jAdy0KaT!pJhE-QhQWjk3Z94tF3jx4oA14xGNCvxVgRSqB8X2qaY
# https://drive.google.com/open?id=0B6TockxTwgQUckhqV0JNcXp1Qm8
# https://mega.nz/#!3FV2kbrD!O904dpJEy8TYxquFHbxNTGU3QgDSBwYr-IpW4FZNVww
# https://drive.google.com/file/d/1Qm76WYTl4Xh3fUKWmVv1sk0wXFG6a0kX/view?usp=sharing
# https://mega.nz/#!iddw2AhD!OBDhLh6ELwMe4bloA10nV4KAm8rsYXTzZzwn8W4FeQ8
# https://mega.nz/#!aVlAXb7B!FLYpQFHhW_-rGvf4pLpphETw7FTOV5qPTffNaW5mHKU
# https://mega.nz/#!GRM0DaIC!M_pNTiAR8wBhyUdkULQNBhfzm-qC0a9Vl_0LwZ-ooU8
# https://mega.nz/#!rYkyDRLB!ri1_Fg8AUd1ifSmMB9ODYq-eVkwteUFvLZsrolfYbqE
# https://drive.google.com/file/d/1oWcYvfUGmpaFV_I8oB2QTDlnlWkb44yp/view?usp=sharing
# https://mega.nz/#!rN1S0YbK!40SFjSb-uWcaC9WRuwj0W6pLWKzoDtaZ9H1byMlbFIk

# %% [markdown]
# ### 5-1-2 Get related infomation of HTML tag

# %% [markdown]
# * After get the specific tag, we can use the following property to get related data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ex,

# %%
import requests 
from bs4 import BeautifulSoup

url = "https://fchart.github.io/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "lxml")
tags = soup("a")
tag = tags[12]
print("----------------")
print("tag:", tag)
print("----------------")
print("URL: ", tag.get("href", None))
print("Tag Content: ", tag.text)
print("target Property: ", tag["target"])
tags = soup("img")
tag = tags[1]
print("----------------")
print("tag:", tag)
print("----------------")
print("Image URL: ", tag.get("src", None))
print("alt property: ", tag["alt"])
print("Property: ", tag.attrs)
# Out:
# ----------------
# tag: <a class="btn btn-info" href="http://blockly.is-best.net/" style="font-size:small" target="_blank"><b>ESP8266 Blockly for MicroPython 英文線上版</b></a>
# ----------------
# URL:  http://blockly.is-best.net/
# Tag Content:  ESP8266 Blockly for MicroPython 英文線上版
# target Property:  _blank
# ----------------
# tag: <img alt="fChart直譯器圖例" class="img-fluid rounded mb-3 mb-md-0" src="img/fchart01.png"/>
# ----------------
# Image URL:  img/fchart01.png
# alt property:  fChart直譯器圖例
# Property:  {'class': ['img-fluid', 'rounded', 'mb-3', 'mb-md-0'], 'src': 'img/fchart01.png', 'alt': 'fChart直譯器圖例'}

# %% [markdown]
# ### 5-1-3 Use BeautifulSoup to Search HTML Tag

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * in this episode we will use: https://fchart.github.io/Elements.html to test
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Use select() & select_one() to search HTML tag:

# %%
import requests
from bs4 import BeautifulSoup 

url = "https://fchart.github.io/Elements.html"
response = requests.get(url)
print("*********************")
print("HTML", response.text)
print("*********************")
soup = BeautifulSoup(response.text, "lxml")
tag = soup.select_one("h2")
print("h2: ", tag.text)
tags = soup.select("b")
print("b: ", tags[0].text)
tag = soup.select_one("#q2")
tag2 = tag.select_one("b")
print("b: ", tag2.text)
tags = soup.select(".response")
print("li: ", tags[0].text)
print("li: ", tags[1].text)
print("li: ", tags[2].text)
print("li: ", tags[3].text)
# Out:
# *********************
# HTML <!DOCTYPE html>
# <html lang="big5">
#  <head>
#   <meta charset="utf-8"/>
#   <title>HTML清單標籤</title>
#   <style>
#   .question { color: brown }
#   .answer { font-size: 12pt; color: green }
#   </style>
#  </head>
#  <body>
#    <h2 id="main">問卷調查</h2>
#    <ol id="survey" class="survey">
#     <li id="q1" class="question"><b>請問你的性別?</b>
#       <ul class="answer">
#         <li class="response">男</li>
#         <li class="response selected">女</li>
#       </ul>
#     </li>
#     <li id="q2" class="question"><b>請問你是否喜歡偵探小說?</b>
#       <ul class="answer">
#         <li class="response">喜歡</li>
#         <li class="response selected">不喜歡</li>
#       </ul>
#     </li>
#     <li id="q3" class="question"><b>請問你是否會 HTML 網頁設計?</b>
#       <ul class="answer">
#         <li class="response selected">會</li>
#         <li class="response">不會</li>
#       </ul>
#     </li>
#   </ol>
#  </body>
# </html>
# *********************
# h2:  問卷調查
# b:  請問你的性別?
# b:  請問你是否喜歡偵探小說?
# li:  男
# li:  女
# li:  喜歡
# li:  不喜歡

# %% [markdown]
# 2. Use find() & find_all() to search HTML tag:

# %%
import requests
from bs4 import BeautifulSoup 

url = "https://fchart.github.io/Elements.html"
response = requests.get(url)
soup = BeautifulSoup(response.text, "lxml")
tag = soup.find("h2")
print("h2: ", tag.text)
tag = soup.find("b")
print("b: ", tag.text)
tags = soup.find_all("b")
print("b: ", tags[0].text)
tag = soup.find("li", {"id":"q2"})
tag_q = tag.find("b")
print("Question: ", tag_q.text)
tags_a = tag.find_all("li", {"class":"response"})
for tag in tags_a:
    print("Ans: ", tag.text)
# Out:
# h2:  問卷調查
# b:  請問你的性別?
# b:  請問你的性別?
# Question:  請問你是否喜歡偵探小說?
# Ans:  喜歡
# Ans:  不喜歡

# %% [markdown]
# * With class=:

# %%
import requests
from bs4 import BeautifulSoup 

url = "https://fchart.github.io/Elements.html"
response = requests.get(url)
soup = BeautifulSoup(response.text, "lxml")
tag = soup.find("h2")
print("h2: ", tag.text)
tag = soup.find("b")
print("b: ", tag.text)
tags = soup.find_all("b")
print("b: ", tags[0].text)
tag = soup.find("li", {"id":"q2"})
tag_q = tag.find("b")
print("Question: ", tag_q.text)
tags_a = tag.find_all("li", class_="response")
for tag in tags_a:                           
    print("Ans: ", tag.text)
# Out:
# h2:  問卷調查
# b:  請問你的性別?
# b:  請問你的性別?
# Question:  請問你是否喜歡偵探小說?
# Ans:  喜歡
# Ans:  不喜歡

# %% [markdown]
# * find_all() can use "limit" parameter limit the number:

# %%
import requests
from bs4 import BeautifulSoup 

url = "https://fchart.github.io/Elements.html"
response = requests.get(url)
soup = BeautifulSoup(response.text, "lxml")
tags_li = soup.find_all("li", class_="response", limit=3)
print(tags_li)
# Out:
# [<li class="response">男</li>, <li class="response selected">女</li>, <li class="response">喜歡</li>]

# %% [markdown]
# 3. Use find_next() to search next HTML tag:

# %%
import requests
from bs4 import BeautifulSoup 

url = "https://fchart.github.io/Elements.html"
response = requests.get(url)
soup = BeautifulSoup(response.text, "lxml")
tag_ans1 = soup.find("li", class_="response")
print(tag_ans1.text)
tag_ans2 = tag_ans1.find_next()
print(tag_ans2.text)
# Out:
# 男
# 女

# %% [markdown]
# ## 5-2 Use regular expression to fetch web data

# %% [markdown]
# ### 5-2-1 Know the regular expression

# %% [markdown]
# [A-Z0-9]{8}:
#
# [A-Z0-9]: define what char show in strings
# {8}: define how to compare, usually means homw many times char shows, or it locates

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Also can use () as substring, ex:
# * "a(bc)*"
# * "(b | ef)gh"
# * "[0-9]+"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Some samples:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5-2-2 Python's re module usage:

# %% [markdown]
# 1. import re

# %% [markdown]
# 2. example, use regular expression find the email address of str1

# %% [markdown]
# str1 = """Joe's email is joe@gmail.com, Tom's email is tom@yahoo.com"""

# %% [markdown]
# #### Use search() method:

# %% [markdown]
# * In re's search() can search the first matched substring:

# %%
import re

str1 = """Joe's email is joe@gmail.com,  
Tom's email is tom@yahoo.com"""
match = re.search(r"[\w.-]+@[A-Za-z0-9_.-]+", str1)
if match:
    print(match.group())
else:
    print("Doesn't find!")
# Out:
# joe@gmail.com

# %% [markdown]
# #### Group Capturing

# %%
import re

str1 = """Joe's email is joe@gmail.com,  
Tom's email is tom@yahoo.com"""

match = re.search(r"([\w.-]+)@([A-Za-z0-9_.-]+)", str1)
if match:
    print(match.group())
    print(match.group(1))
    print(match.group(2))
else:
    print("沒有找到符合的字串!")
# Out:
# joe@gmail.com
# joe
# gmail.com

# %% [markdown]
# #### Use findall() method:

# %%
import re

str1 = """Joe's email is joe@gmail.com,  
Tom's email is tom@yahoo.com"""
match = re.findall(r"[\w.-]+@[A-Za-z0-9_.-]+", str1)
if match:
    print(match)
else:
    print("沒有找到符合的字串!")
# Out:
# ['joe@gmail.com', 'tom@yahoo.com']

# %% [markdown]
# #### Use compile() method
# * compile() method can let trregular expression string into Pattern Object

# %%
import re

str1 = """Joe's email is joe@gmail.com,  
Tom's email is tom@yahoo.com"""
pattern = re.compile(r"[\w.-]+@[A-Za-z0-9_.-]+")
match = re.search(pattern, str1)
if match:
    print(match.group())
else:
    print("沒有找到符合的字串!")
# Out:
# joe@gmail.com

# %% [markdown]
# ### 5-2-3 Use regular expression analyze HTML webpage

# %%
# because some of the href value is not started with "http"

import requests
import re

url = "https://fchart.github.io/"
response = requests.get(url)
links = re.findall(r'href="https://.*?"', response.text)
for link in links:
    print(link)
# Out:
# href="https://hueyanchen.github.io/"
# href="https://fchart.github.io/MyMind/index_zh-Hant.html"
# href="https://drive.google.com/file/d/1NKyh1nl1vwyhHf7mOLj7cxb2g6SpSx57/view?usp=sharing"
# href="https://drive.google.com/file/d/1PeCYYT-xA3v9Wn7LiwM2wq8ltvJVwGqY/view?usp=sharing"
# href="https://github.com/fchart/fChartExamples2"
# href="https://fchart.github.io/fChart6%E4%BD%BF%E7%94%A8%E6%89%8B%E5%86%8A.pdf"
# href="https://fchart.github.io/tutorial/"
# href="https://fchart.github.io"
# href="https://fchart.github.io/fChart6%E4%BD%BF%E7%94%A8%E6%89%8B%E5%86%8A.pdf"
# href="https://drive.google.com/file/d/1NKyh1nl1vwyhHf7mOLj7cxb2g6SpSx57/view?usp=sharing"
# href="https://drive.google.com/file/d/1NKyh1nl1vwyhHf7mOLj7cxb2g6SpSx57/view?usp=sharing"
# href="https://hueyanchen.github.io/"
# href="https://drive.google.com/file/d/1VspHydl48PIoeVT7sjw4Gx307UrJUNHB/view?usp=sharing"
# href="https://mega.nz/file/SNlw2TyY#XUIiHxhjY90iQsM0fa5Ys1RgaGkm0AmoZDPEU2amfRM"
# href="https://drive.google.com/file/d/1fiIEaE55--xofBrpK7h2SPXp0nLzi3tS/view?usp=sharing"
# href="https://mega.nz/file/CIVEUA7b#Gr_BSUJRTFwgbSv6_kV8ev_SvXWSJ8o48J7JKRQuaHo"
# href="https://drive.google.com/file/d/1RUK_1IO2Eu4NhC7sR-DmCrcICAjOUwO4/view?usp=sharing"
# href="https://drive.google.com/file/d/1Mm5r9XIdt4yTkrZSuAd-nq5SdYErWDGg/view?usp=share_link"
# href="https://mega.nz/file/zE8SnBja#nJAUXkKWWJdFi-_c0dIXFuqSMhCkh-VhAIHUycqf7tg"
# href="https://drive.google.com/file/d/1EkUZPiNGmCNxzEPtDNkffyz5ngmLWa3M/view?usp=share_link"
# href="https://mega.nz/file/KQVlRAhR#c7-tWIJ6Kzz7tcTkYHd1kmr8oDAicupkSCO9tO4O470"
# href="https://drive.google.com/file/d/1hvnBeY67kOh8OSNqTCMC69qJyGFzDPzi/view?usp=sharing"
# href="https://mega.nz/file/iUlRFY6K#aaZa9aVI3eODX_ZHEnwPmldj4r5yqHs3mPp_a4GBFxM"
# href="https://drive.google.com/file/d/1oGrkL2Anld0q2oOeXlHZHqn8dqKQb2oJ/view?usp=sharing"
# href="https://drive.google.com/file/d/1j28k603m6UrW19_armtFtKWXUopt_ZHb/view?usp=sharing"
# href="https://mega.nz/file/7VVhFaSQ#2iFw13Iw6vDonMwsBVsvwlN7XhKpnBn7kfgyB4kqBrc"
# href="https://drive.google.com/file/d/15P73WtLjmaqEvVVNa0m_IFP9xs89DvBC/view"
# href="https://mega.nz/file/ydcUEATI#Vyr7OriYcqr7doJ66bDyvuqntGs64E3OLLjrI-ojF34"
# href="https://drive.google.com/file/d/1WlAgVh9gQYjTzdHJmCFDfcjExy8FUKRc/view?usp=sharing"
# href="https://mega.nz/file/CclhVSjY#ZyupR_jmkkK8lrNGxzuXLz-zwGesG-rZ27Imxt64H7M"
# href="https://drive.google.com/file/d/1JGB222NhJOMc7cwqHFovsiEN3tmibI6d/view?usp=sharing"
# href="https://drive.google.com/file/d/1edveDAfA7IfrqPGkLXenSpYd0kejwepv/view?usp=sharing"
# href="https://mega.nz/file/2A0ghbpR#AHmzzgxPeh0_a2h-m0JwzPHyyG4IAs8ngmx8jqNAyJ8"
# href="https://drive.google.com/file/d/1UC7uGxVo-xxjbGj5AL_5dS1TimRZ1s8h/view?usp=sharing"
# href="https://drive.google.com/file/d/1Bmh37My3A_eeVacvecyzJyTu6lAwFFqA/view?usp=sharing"
# href="https://drive.google.com/file/d/1gmiXape570wbYmgZcOLdkzX0lbMrfi17/view?usp=sharing"
# href="https://drive.google.com/file/d/1tUZeVOQkS1YIL0PdZ0u5jgmBxcXGyuX4/view?usp=sharing"
# href="https://mega.nz/file/nBV3gK7L#Ss9_syfqWikVFcCkgkD4gYIX9rF4_RUMhpeG6lhzbBA"
# href="https://drive.google.com/file/d/1eJPJJ3v6kHV1kSMg9n4XYMZi8jPzFafa/view?usp=sharing"
# href="https://drive.google.com/file/d/1g1QL9APHWXPdYX8MFaOPAqGnJMd6WsuE/view?usp=sharing"
# href="https://mega.nz/file/uJ9ClRzQ#sJedtjXLfglCItkKJ4W1V1DGWjt2jOZYcWXErWOK_ww"
# href="https://drive.google.com/file/d/1JGeFy09wFtpTdodYnjevgIdEc_3Ll9kQ/view?usp=sharing"
# href="https://drive.google.com/file/d/1BL1v-hbrTdEXpTcvInBx4IduGT7qlBEr/view?usp=sharing"
# href="https://mega.nz/file/KdNUVbTQ#wjFl6-iNNfZuVrbaWaJaXD1099R4JUyrJ2RuKW3gRQg"
# href="https://drive.google.com/file/d/1-nK3S5nYxActBsxF-pP63XsLUnsd7CKb/view?usp=sharing"
# href="https://mega.nz/file/7F93TAKJ#UCChyzf8rIdPN21KH8sPmXvoz_e9UU2Ve41nk_wZLVc"
# href="https://drive.google.com/file/d/1S3wpgIwy0_rERpLt1sDhNatT9hI-zm3p/view?usp=sharing"
# href="https://mega.nz/file/XZkg3TpK#jqjl8191KtHcmUywLmG1mLegEBNRZ-eq-5-LrwIqRPU"
# href="https://drive.google.com/file/d/1n-744s9LCbxSJ25cX8ke0qR1W7Ainm6s/view?usp=sharing"
# href="https://mega.nz/file/KRlAgT7b#g2sbn1YeQkF1m0LcC1GH0Z2kq_60ishHDhPy5e11Keg"
# href="https://drive.google.com/file/d/1323dhbPkZ1Pj1CqLQ45r-tfJQeuvqWRT/view?usp=sharing"
# href="https://mega.nz/file/yIk2xDpB#s3AKcQBN5OTQD3Rg4i_0ECLnHvag-rz5R_ZPXIePlPM"
# href="https://drive.google.com/file/d/1gdWFf4DBheVH8SuPrCuYaIYsNByx2t9V/view?usp=sharing"
# href="https://mega.nz/#!aEEEiQ7Z!G_VXHVAn_l3mCxOmBLPq_ZWMFtkEmVLpWLfzWMuv3yY"
# href="https://drive.google.com/file/d/1tvnq3yKp6BJtuh-itHaDUVZLC0G7Ap5Y/view"
# href="https://mega.nz/file/TdkXACYK#VusZ9ZJebLEH9ZwAebQ5778Hz1lzahrp9j2BQ2Lbn14"
# href="https://drive.google.com/file/d/1qyx0zxJIFTRmMtAY5G2AmreUKeOm94kC/view?usp=sharing"
# href="https://mega.nz/file/WF9FGYzJ#3CZnzeK0PHYruqangJRVQhtuWG79014fzwqPjpQpBMk"
# href="https://drive.google.com/file/d/1JTT2rcz1VOWx81HgW2e_MCHtyANkY3Qn/view?usp=sharing"
# href="https://mega.nz/#!LNsyXSaR!fe4CxK9sNCvmEzvGjUE_TjJW4PtJtyJNEWYfgb8sz0g"
# href="https://drive.google.com/file/d/0B6TockxTwgQUcGk5a1o0RVpzNDQ/view?usp=sharing"
# href="https://mega.nz/#!3ckhFQQY!lG5lDuW1rKnmJI5ikU13hJC5vazbmwCgmlN9m9FkL0c"
# href="https://drive.google.com/file/d/1ZAHEh8rrC_RxRJ5XEUyd2JReV5Zap5C4/view?usp=sharing"
# href="https://mega.nz/#!eY9SlSAA!sSNlzoyDf-1ZV2xdDWnDj6ZSEZ7gHbwcE5TVwW-e-0w"
# href="https://media.readthedocs.org/pdf/microbit-micropython/latest/microbit-micropython.pdf"
# href="https://drive.google.com/file/d/16ZAPNifmijNKG9BXRh93Rwm0KnHympyT/view?usp=sharing"
# href="https://app.box.com/s/p9ze4e1c1q5tlgay4a8kxwoddjqafufq"
# href="https://drive.google.com/file/d/1UF0NXUdK0gqQ33jhpX_xCt9sThee2Ft4/view?usp=sharing"
# href="https://app.box.com/s/2jyxz2tw8afoo71p5895j8q7kqr7j2q9"
# href="https://drive.google.com/file/d/1JvU4MDt6TD0V5h1NGQ8U5A_r-lZY4Qty/view?usp=sharing"
# href="https://app.box.com/s/b5143gnb26jyghlsn7r837clcaovaa37"
# href="https://drive.google.com/file/d/1KFx5JdYqc4jtNZ3_5aDEhdqwITiDVKc5/view?usp=sharing"
# href="https://mega.nz/#!WBknGYCD!Cbw03FRMjy-gcFjay8quyBsoSVcADg1qQ9_6vKvFlN4"
# href="https://drive.google.com/file/d/1bh0Utb5NxbU9vvVe7Re5MduPOWXeagRy/view?usp=sharing"
# href="https://mega.nz/#!OM8kAIwZ!k6SgN8rh3aPEgXwm_FlsgiHjIrhqY20l-nRRTqbnN7k"
# href="https://drive.google.com/file/d/1OwAM4cCOpA_Uv9UckKLIcPLt4-eO9xZk/view?usp=sharing"
# href="https://mega.nz/#!vJVkEYRI!dbp3s8_hM3ng0MltEJPkH222yvOB3xSOki0PWzy1dNg"
# href="https://www.tenlong.com.tw/items/9864630725?item_id=1011985"
# href="https://www.tenlong.com.tw/items/9864632787?item_id=1023174"
# href="https://www.tenlong.com.tw/items/9572192248?item_id=887436"
# href="https://www.tenlong.com.tw/items/9864632760?item_id=1022152"
# href="https://www.tenlong.com.tw/items/9863123226?item_id=1012678"
# href="https://www.tenlong.com.tw/products/9789863124245"
# href="https://drive.google.com/file/d/19dE_FOSq_tsOOZ_9nRuzCeEWh1USaOFJ/view?usp=sharing"
# href="https://drive.google.com/file/d/1-nK3S5nYxActBsxF-pP63XsLUnsd7CKb/view?usp=sharing"
# href="https://drive.google.com/file/d/1NSlLwYs5A9sjbeDIIm8VHjDYVhqgHZLm/view?usp=sharing"
# href="https://drive.google.com/file/d/1gdWFf4DBheVH8SuPrCuYaIYsNByx2t9V/view?usp=sharing"
# href="https://drive.google.com/file/d/1JTT2rcz1VOWx81HgW2e_MCHtyANkY3Qn/view?usp=sharing"
# href="https://drive.google.com/file/d/1UF5BbavQzC3JZOV7xkvTvYcL5WJAsZWq/view?usp=sharing"
# href="https://drive.google.com/file/d/12n-hXBzsgE942TsifWGIPl4qXF9pOZZa/view?usp=sharing"
# href="https://drive.google.com/file/d/1zLs9eR6IH_xliJfd18hjfdNf9ISowxfS/view?usp=sharing"
# href="https://drive.google.com/file/d/1YfIQjQ9Z7cz3ILcRGprFOgONSqoWGxqQ/view?usp=sharing"
# href="https://drive.google.com/file/d/1YGBxT4r5xAGnEaG7TsUUx5UhJFOI97Xa/view?usp=sharing"
# href="https://drive.google.com/file/d/122pDfI4Bw57vTldRkyuXA0cSu5vx2v0T/view?usp=sharing"
# href="https://drive.google.com/file/d/1aRdXM2hDCaOFHIQEHWT6JIMV6RfTEBZV/view?usp=sharing"
# href="https://drive.google.com/file/d/0B6TockxTwgQUN2t1MUlLQTIxVGc/view?usp=sharing"
# href="https://drive.google.com/file/d/0B6TockxTwgQUYlNVSHpINGw2ajA/view?usp=sharing"
# href="https://drive.google.com/file/d/0B6TockxTwgQUWnVtNUdoYXA0M3M/view?usp=sharing"
# href="https://drive.google.com/file/d/0B6TockxTwgQUNmdOSmNibjM3OVE/view?usp=sharing"
# href="https://drive.google.com/file/d/0B6TockxTwgQUMnpmZFRnem9kVHM/view?usp=sharing"
# href="https://mega.nz/file/bNcW2QyC#NfK-VYCujZxdQt1F2RNwOPf1Aj7ph-bB673wQln3BO8"
# href="https://mega.nz/file/udVBVSwC#BMjBsyJxmL9I4zupRhqFrxDxUu35w1vN8Z7H56chOCM"
# href="https://mega.nz/#!PYUxjSgR!hhdU3pzSvpuJEPPO7mGc9UdsFUP-YIR_x6S2d7XEPQc"
# href="https://mega.nz/#!aEEEiQ7Z!G_VXHVAn_l3mCxOmBLPq_ZWMFtkEmVLpWLfzWMuv3yY"
# href="https://mega.nz/#!LNsyXSaR!fe4CxK9sNCvmEzvGjUE_TjJW4PtJtyJNEWYfgb8sz0g"
# href="https://mega.nz/#!jNNxxCLT!QWwmUyOXTlS_0OQm_7QVNOwZaScvsi3wIxsIvkB1Fe8"
# href="https://mega.nz/#!eE0EUAjZ!7zgBcHHQPtBggV50XF-v7MYgqtoApC_ANXv9xIr35A8"
# href="https://mega.nz/#!rEdizaAb!6bkyIN1JGkwS618SifKFF1kdGvDXNZGjCVfbI4ieJwI"
# href="https://mega.nz/#!eZMgRKJL!p8SZgjMj4R6Ov0cb836vmDtoLIb587TddzgqrrQhJ6g"
# href="https://mega.nz/#!2VsHEBJJ!whVtiXjc37a-uD0cMljCJ7Le7iV3cqJRBh8JFHH05Oo"
# href="https://mega.nz/#!qQdBVKQa!huTtgYsVQF44-FrfA3wi9sNh54TICTzuR2qdMeVhWqw"
# href="https://mega.nz/#!LV9WhCAZ!XgvEtQ48OMkCJgya9CADJTFjij2Jhf9Ng-AGcr6Io74"
# href="https://mega.nz/#!CVVnAJQT!3FlAub7Vk0OylH5m8n32wDc_hn8F4d3VXuCb3bGvmJk"
# href="https://mega.nz/#!fQMHBDrT!i-M5Vlqw7Rb_m-U7itLJ0zhpmHbSr30eVLE3lsc6DyY"
# href="https://mega.nz/#!uBMgSbpC!WUVi6lyLxmvvi3ppmKDOH9oxjiEu2I2a-rZaEbtGXew"
# href="https://mega.nz/#!Scc1GDRA!u8AAtjdfeWxN49O6O929qMXXmszM-LzG0D6TE7ZKrew"
# href="https://mega.nz/#!yY0DwAxA!b8NDb19w9Sp7PibH4JedhLQGoepO1cN4grK_4idGDOo"
# href="https://mega.nz/#!3REjiLaa!bwXMhIbnZNBR1GtA4w-QDnPJFjJsbJjq8Oh5tnjfWD8"
# href="https://github.com/fchart/fChartExamples"
# href="https://github.com/fchart/fChartExamples2"
# href="https://drive.google.com/file/d/1ThvyPWVlyC7ktqnwyMqwx0mo8q9z8p71/view?usp=sharing"
# href="https://mega.nz/#!adsCWKoC!by9fLvh_TerQFptGEdOYaUHjz8ReL72TrH0etAIasv8"
# href="https://drive.google.com/file/d/1tZ2q_12P3tA6mIVlhWvVbw3rrZAubNMn/view?usp=sharing"
# href="https://mega.nz/#!nFVxzCjC!qOyLgLydA5XH8TkxOX5jDwUKqnm4ENnQfxYTJ8nDbKc"
# href="https://drive.google.com/file/d/1Qm76WYTl4Xh3fUKWmVv1sk0wXFG6a0kX/view?usp=sharing"
# href="https://mega.nz/#!iddw2AhD!OBDhLh6ELwMe4bloA10nV4KAm8rsYXTzZzwn8W4FeQ8"
# href="https://drive.google.com/file/d/0B6TockxTwgQUcGk5a1o0RVpzNDQ/view?usp=sharing"
# href="https://mega.nz/#!3ckhFQQY!lG5lDuW1rKnmJI5ikU13hJC5vazbmwCgmlN9m9FkL0c"
# href="https://drive.google.com/file/d/1k0RUE54aHftn59-1WLAr6dGt6Gci05w7/view?usp=sharing"
# href="https://mega.nz/#!jAdy0KaT!pJhE-QhQWjk3Z94tF3jx4oA14xGNCvxVgRSqB8X2qaY"
# href="https://drive.google.com/open?id=0B6TockxTwgQUckhqV0JNcXp1Qm8"
# href="https://mega.nz/#!3FV2kbrD!O904dpJEy8TYxquFHbxNTGU3QgDSBwYr-IpW4FZNVww"
# href="https://drive.google.com/file/d/1Qm76WYTl4Xh3fUKWmVv1sk0wXFG6a0kX/view?usp=sharing"
# href="https://mega.nz/#!iddw2AhD!OBDhLh6ELwMe4bloA10nV4KAm8rsYXTzZzwn8W4FeQ8"
# href="https://mega.nz/#!aVlAXb7B!FLYpQFHhW_-rGvf4pLpphETw7FTOV5qPTffNaW5mHKU"
# href="https://mega.nz/#!GRM0DaIC!M_pNTiAR8wBhyUdkULQNBhfzm-qC0a9Vl_0LwZ-ooU8"
# href="https://mega.nz/#!rYkyDRLB!ri1_Fg8AUd1ifSmMB9ODYq-eVkwteUFvLZsrolfYbqE"
# href="https://drive.google.com/file/d/1oWcYvfUGmpaFV_I8oB2QTDlnlWkb44yp/view?usp=sharing"
# href="https://mega.nz/#!rN1S0YbK!40SFjSb-uWcaC9WRuwj0W6pLWKzoDtaZ9H1byMlbFIk"
